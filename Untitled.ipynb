# %%
import requests

# %%
res = requests.get('https://news.ltn.com.tw/list/breakingnews')
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n    <head>\n        <script> var pvDomain = \'pv.ltn.com.tw\'; </script>\n<script> var pvServer = \'pv.ltn.com.tw\'; </script>\n<script src="https://cache.ltn.com.tw/js/c.js"></script>\n        <base href=\'https://news.ltn.com.tw/\'>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7">\n        <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0">\n        <meta property="og:site_name" content="自由電子報" />\n        <meta name="ltn:device" content="R" />\n        <link rel="shortcut icon" href="assets/images/all/favicon.ico?upload=20170620" />\n        <link rel="apple-touch-icon" href="assets/images/all/ltn.png" />\n        <link rel="apple-touch-icon-precomposed" href="assets/images/all/ltn.png" />\n        <meta name="robots" content="index,follow" />\n        <title>總覽新聞 - 即時 - 自由時報電子報</title>\n<meta charset="utf-8" />\n<meta n
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <script> var pvDomain = 'pv.ltn.com.tw'; </script>
# <script> var pvServer = 'pv.ltn.com.tw'; </script>
# <script src="https://cache.ltn.com.tw/js/c.js"></script>
# <base href="https://news.ltn.com.tw/"/>
# <meta charset="utf-8"/>
# <meta content="IE=10; IE=9; IE=8; IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" name="viewport"/>
# <meta content="自由電子報" property="og:site_name">
# <meta content="R" name="ltn:device">
# <link href="assets/images/all/favicon.ico?upload=20170620" rel="shortcut icon"/>
# <link href="assets/images/all/ltn.png" rel="apple-touch-icon"/>
# <link href="assets/images/all/ltn.png" rel="apple-touch-icon-precomposed"/>
# <meta content="index,follow" name="robots">
# <title>總覽新聞 - 即時 - 自由時報電子報</title>
# <meta charset="utf-8"/>
# ...

# %%
soup.select('.title')[0].text
# soup.find_all(class_="title")
# Out:
# '七夕拜「七娘媽」越來越罕見 文史工作者說原因'

# %%
soup.select('.tit')[0]
# Out:
# <a class="tit" data-desc="T:0:七夕拜「七娘媽」越來越罕見 文史工作者說原因" href="https://news.ltn.com.tw/news/life/breakingnews/3271125">
# <span class="time">17:22</span>
# <p>
# <span class="title">七夕拜「七娘媽」越來越罕見 文史工作者說原因</span>
# <span class="video listS_h" style="display: none;">
# <img src="assets/images/video.svg"/>
# </span>
# </p>
# </a>

# %%
soup.select('.tit')[0].get("href")
# Out:
# 'https://news.ltn.com.tw/news/life/breakingnews/3271125'

# %%
for tmp in soup.select('.tit'):
    title = tmp.select('.title')[0].text
    time = tmp.select('.time')[0].text
    url = tmp.get('href')
    key = url[-7::]
    print(key,title,time,url)
# Out:
# 3271125 七夕拜「七娘媽」越來越罕見 文史工作者說原因 17:22 https://news.ltn.com.tw/news/life/breakingnews/3271125
# 3271152 65歲白冰冰無預警七孔流血 血壓飆250送醫急救 17:22 https://ent.ltn.com.tw/news/breakingnews/3271152
# 3271029 武漢肺炎》港人普篩意願低落 林鄭月娥遷怒專家抹黑計畫 17:22 https://news.ltn.com.tw/news/world/breakingnews/3271029
# 3270976 謝龍介「緊身潛水衣」七夕曬恩愛 網：為什麼不是清德！ 17:21 https://news.ltn.com.tw/news/politics/breakingnews/3270976
# 3271141 宋威龍《以家》公主抱譚松韻 糗「手滑」把人放地上 17:21 https://ent.ltn.com.tw/news/breakingnews/3271141
# 3271124 醉男上路撞死人未和解 法官判5年 17:18 https://news.ltn.com.tw/news/society/breakingnews/3271124
# 3271122 健康網》常說：「蛤？」  可能需要選配助聽器 17:18 https://health.ltn.com.tw/article/breakingnews/3271122
# 3271137 中職》桃猿棒次大調動 陳晨威、林立扛中心打線 17:18 https://sports.ltn.com.tw/news/breakingnews/3271137
# 3271115 詐領出差旅費17次 前國資圖館長呂春嬌被彈劾 17:15 https://news.ltn.com.tw/news/politics/breakingnews/3271115
# 3271035 逮丸郎才解的出來！「台灣人檢定初級」網路上瘋傳 17:14 https://news.ltn.com.tw/news/life/breakingnews/3271035
# ...

# %%
tmp = soup.select('.tit')[0]

# %%
tmp.select('.title')[0].text
# Out:
# '七夕拜「七娘媽」越來越罕見 文史工作者說原因'

# %%
# Out:
# '3271103'

# %%
split(url,'/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-144c20ce11af> in <module>
# ----> 1 split(url,'/')
#
# NameError: name 'split' is not defined
